# %%
# pip install Pillow

# %%
# import scipy; print(scipy.__version__)

# %%
# pip install pillow

# %%
# pip install imagehash

# %%
import imageio
#import imresize
#imageio.imread()

# %%
import matplotlib.gridspec as gridspec
# %matplotlib inline
import time
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# from scipy.misc import  imresize, imshow

# %%
# pip install scipy==1.2.1

# %%
# from scipy import misc

# %%
import scipy.misc

# %%
# scipy.imageio

# %%
# import matplotlib.pyplot as plt

# %%
# import matplotlib.gridspec as gridspec
# %matplotlib inline
# import time
# import numpy as np

# %%
# import hashlib
# from scipy.misc import imread, imresize, imshow
# import matplotlib.pyplot as plt
# import matplotlib.gridspec as gridspec
# %matplotlib inline
# import time
# import numpy as np

# %% [markdown]
# # Removing Duplicate Images Using Hashing

# %%
def file_hash(filepath):
    with open(filepath, 'rb') as f:
        return md5(f.read()).hexdigest()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sdass\\Video to pdf'

# %%
os.chdir(r'C:\Users\sdass\Video to pdf\images')
os.getcwd()
# Out:
# 'C:\\Users\\sdass\\Video to pdf\\images'

# %%
file_list = os.listdir()
print(len(file_list))
# Out:
# 4453

# %%
import hashlib, os
duplicates = []
hash_keys = dict()
for index, filename in  enumerate(os.listdir('.')):  #listdir('.') = current directory
    if os.path.isfile(filename):
        with open(filename, 'rb') as f:
            filehash = hashlib.md5(f.read()).hexdigest()
        if filehash not in hash_keys: 
            hash_keys[filehash] = index
        else:
            duplicates.append((index,hash_keys[filehash]))

# %%
duplicates
# Out:
# []

# %%
for file_indexes in duplicates[:30]:
    try:
    
        plt.subplot(121),plt.imshow(imageio.imread(file_list[file_indexes[1]]))
        plt.title(file_indexes[1]), plt.xticks([]), plt.yticks([])

        plt.subplot(122),plt.imshow(imageio.imread(file_list[file_indexes[0]]))
        plt.title(str(file_indexes[0]) + ' duplicate'), plt.xticks([]), plt.yticks([])
        plt.show()
    
    except OSError as e:
        continue

# %% [markdown]
# # Delete Files After Printing

# %%
for index in duplicates:
    os.remove(file_list[index[0]])

# %%
from PIL import Image
import imagehash
import os
import numpy as np

# %%
def find_similar(self,location,similarity=80):
        fnames = os.listdir(os.getcwd())
        hash_size =8
        threshold = 1 - similarity/100
        diff_limit = int(threshold*(hash_size**2))
        
        with Image.open(location) as img:
            hash1 = imagehash.average_hash(img, hash_size).hash
        
        print("Finding Similar Images to {} Now!\n".format(location))
        for image in fnames:
            with Image.open(os.listdir(os.getcwd()),image) as img:
                hash2 = imagehash.average_hash(img, hash_size).hash
                
                if np.count_nonzero(hash1 != hash2) <= diff_limit:
                    print("{} image found {}% similar to {}".format(image,similarity,location))
# Out:
#   File "C:\Users\sdass\AppData\Local\Temp/ipykernel_29432/575436063.py", line 7
#     with Image.open(os.listdir(os.getcwd()) as img:
#                                             ^
# SyntaxError: invalid syntax

# %%
# from DuplicateRemover import DuplicateRemover

# dirname = "images"

# Remove Duplicates
# dr = DuplicateRemover(dirname)
# dr.find_duplicates()

# Find Similar Images

find_similar("frame26.jpg",70)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2978     try:
# -> 2979         fp.seek(0)
#    2980     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'int' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29432/4071118934.py in <module>
#       9 # Find Similar Images
#      10
# ---> 11 find_similar("frame26.jpg",70)
#
# ~\AppData\Local\Temp/ipykernel_29432/2962098716.py in find_similar(self, location, similarity)
#       5         diff_limit = int(threshold*(hash_size**2))
#       6
# ----> 7         with Image.open(location) as img:
#       8             hash1 = imagehash.average_hash(img, hash_size).hash
# ...

# %%
os.getcwd()

# %%
os.listdir(os.getcwd())

# %%
similarity=80

# %%
fnames = os.listdir(os.getcwd())
hash_size =8
threshold = 1 - similarity/100
diff_limit = int(threshold*(hash_size**2))

# %%
fnames
# Out:
# ['frame0.jpg',
#  'frame1.jpg',
#  'frame10.jpg',
#  'frame100.jpg',
#  'frame1000.jpg',
#  'frame10000.jpg',
#  'frame10001.jpg',
#  'frame1001.jpg',
#  'frame1002.jpg',
#  'frame10045.jpg',
#  'frame10046.jpg',
#  'frame10047.jpg',
#  'frame10048.jpg',
#  'frame10049.jpg',
#  'frame10050.jpg',
#  'frame10051.jpg',
#  'frame10052.jpg',
#  'frame10053.jpg',
#  'frame10054.jpg',
#  'frame10055.jpg',
#  'frame10071.jpg',
#  'frame10072.jpg',
#  'frame10073.jpg',
#  'frame10074.jpg',
#  'frame10075.jpg',
#  'frame10076.jpg',
#  'frame10077.jpg',
#  'frame10078.jpg',
#  'frame10079.jpg',
#  'frame10080.jpg',
#  'frame10081.jpg',
#  'frame10082.jpg',
#  'frame10083.jpg',
#  'frame10084.jpg',
#  'frame10085.jpg',
#  'frame10086.jpg',
#  'frame10087.jpg',
#  'frame101.jpg',
#  'frame10105.jpg',
#  'frame10106.jpg',
#  'frame10107.jpg',
#  'frame10108.jpg',
#  'frame10109.jpg',
#  'frame10110.jpg',
#  'frame10111.jpg',
#  'frame10112.jpg',
#  'frame10113.jpg',
#  'frame10114.jpg',
# ...

# %%
diff_limit
# Out:
# 12

# %%
location = os.getcwd()

# %%
with Image.open(os.getcwd()) as img:
    hash1 = imagehash.average_hash(img, hash_size).hash
#     print(img)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29432/616888085.py in <module>
# ----> 1 with Image.open(os.getcwd()) as img:
#       2     hash1 = imagehash.average_hash(img, hash_size).hash
#       3 #     print(img)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\sdass\\Video to pdf\\images'

# %%
from DuplicateRemover import DuplicateRemover

dirname = os.getcwd()

# Remove Duplicates
dr = DuplicateRemover(dirname)
# dr.find_duplicates()

# # Find Similar Images
# dr.find_similar("IMG-20110704-00007.jpg",70)

# %%
dr.find_similar("frame28.jpg",70)
# Out:
# Finding Similar Images to frame28.jpg Now!
#
# frame100.jpg image found 70% similar to frame28.jpg
# frame101.jpg image found 70% similar to frame28.jpg
# frame102.jpg image found 70% similar to frame28.jpg
# frame103.jpg image found 70% similar to frame28.jpg
# frame104.jpg image found 70% similar to frame28.jpg
# frame105.jpg image found 70% similar to frame28.jpg
# frame106.jpg image found 70% similar to frame28.jpg
# frame107.jpg image found 70% similar to frame28.jpg
# frame108.jpg image found 70% similar to frame28.jpg
# frame109.jpg image found 70% similar to frame28.jpg
# frame11.jpg image found 70% similar to frame28.jpg
# frame110.jpg image found 70% similar to frame28.jpg
# frame111.jpg image found 70% similar to frame28.jpg
# frame112.jpg image found 70% similar to frame28.jpg
# frame113.jpg image found 70% similar to frame28.jpg
# frame114.jpg image found 70% similar to frame28.jpg
# frame115.jpg image found 70% similar to frame28.jpg
# ...

# %%
import pandas as pd
import numpy as np

# %%
#Finding the duplicate of the images
#ref https://stackoverflow.com/questions/71109424/remove-image-duplicates-using-hashing-in-python

# %%
def calculate_hash(dir):
    """Generate Hash Values for all images in a directory

    Args:
        dir (str): Directory to search for images

    Returns:
        hash_values (list): List of hash values for all images in the directory
        image_ids (list): List of image ids for all images in the directory
    """

    hash_values = []
    image_ids = []

    for file in os.listdir(dir):

        path = os.path.join(dir, file)
        img = Image.open(path)

        hash = imagehash.average_hash(img)

        hash_values.append(hash)
        image_ids.append(file)

    return image_ids, hash_values

# %%
image_ids, hash_values = calculate_hash("C:/Users/sdass/test_duplicates\images")

# %%
hash_values
# Out:
# [array([[False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False]]),
#  array([[False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False],
# ...

# %%
def prepare_dataframe(image_ids, hash_values):

    # Create DataFrame with hash values and image ids
    df = pd.DataFrame(
        {
            "image_ids": image_ids, 
            "hash_values": hash_values, 
            }
    )

    # Create new columns in df with image_ids having hash difference value=0 
    for i in range(len(df.image_ids)):
        df[f"diff_{image_ids[i]}"] = 0

    return df

# %%
df = prepare_dataframe(image_ids, hash_values)
# Out:
# C:\Users\sdass\AppData\Local\Temp/ipykernel_17660/1251263233.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"diff_{image_ids[i]}"] = 0

# %%
df
# Out:
#           image_ids       hash_values  diff_frame0.jpg  diff_frame1.jpg  \
# 0        frame0.jpg  0000000000000000                0                0
# 1        frame1.jpg  0000000000000000                0                0
# 2       frame10.jpg  fffffffffffffffc                0                0
# 3      frame100.jpg  ffff1b01000400f9                0                0
# 4     frame1000.jpg  0d02430707070f0b                0                0
# ...             ...               ...              ...              ...
# 4448  frame9989.jpg  1f1f1f1f1b1b1d1d                0                0
# 4449   frame999.jpg  0d02430707070f0b                0                0
# 4450  frame9990.jpg  1f1f1f1f1b1b1d1d                0                0
# 4451  frame9991.jpg  1f1f1f1f1b1b1d1d                0                0
# 4452  frame9992.jpg  1f1f1f1f1b1b1d1d                0                0
#
#       diff_frame10.jpg  diff_frame100.jpg  diff_frame1000.jpg  \
# ...

# %%
def calculate_differences(df):

    # Obtain difference for every image_id one by one
    for i in range(len(df.hash_values)):
        differences = []

        for j in range(len(df.hash_values)):
            differences.append(df.hash_values[i] - df.hash_values[j])

        # Store the difference values for every image_id
        df.iloc[i, 2:] = differences

    return df

# %%
df = calculate_differences(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17660/3507851425.py in <module>
# ----> 1 df = calculate_differences(df)
#
# ~\AppData\Local\Temp/ipykernel_17660/898289210.py in calculate_differences(df)
#       9
#      10         # Store the difference values for every image_id
# ---> 11         df.iloc[i, 2:] = differences
#      12
#      13     return df
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1728         if take_split_path:
# ...

# %%
#pip install pgmagick
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\sdass\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\sdass\\AppData\\Local\\Temp\\pip-install-gbt22nzq\\pgmagick_2d4d2fae24144bcbaff2b465cf4e9f53\\setup.py'"'"'; __file__='"'"'C:\\Users\\sdass\\AppData\\Local\\Temp\\pip-install-gbt22nzq\\pgmagick_2d4d2fae24144bcbaff2b465cf4e9f53\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\sdass\AppData\Local\Temp\pip-pip-egg-info-aor3utpc'
#          cwd: C:\Users\sdass\AppData\Local\Temp\pip-install-gbt22nzq\pgmagick_2d4d2fae24144bcbaff2b465cf4e9f53\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
# ...

# %%
# import os
# from os import listdir
# from os.path import isfile, join 
# from pgmagick import Image

# mypath = "C:\\Users\\sdass\\Pictures\\FreeVideoToJPGConverter\\1. Python for data mining (11-1-2022 12-59-17 PM)" # path to your Image directory 

# for each_file in listdir(mypath):
#     if isfile(join(mypath,each_file)):
#         image_path = os.path.join(mypath,each_file)
#         pdf_path =  os.path.join(mypath,each_file.rsplit('.', 1)[0]+'.pdf')
#         img = Image(image_path)
#         img.write(pdf_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17660/365437985.py in <module>
#       2 from os import listdir
#       3 from os.path import isfile, join
# ----> 4 from pgmagick import Image
#       5
#       6 mypath = "C:\\Users\\sdass\\Pictures\\FreeVideoToJPGConverter\\1. Python for data mining (11-1-2022 12-59-17 PM)" # path to your Image directory
#
# ModuleNotFoundError: No module named 'pgmagick'
