# %%
# please note this package - imagededup was custom-installed in this kernel 
from imagededup.methods import CNN
from imagededup.utils import plot_duplicates
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 10)

# %%
cnn = CNN()
# Out:
# C:\Users\sdass\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\sdass\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 2022-11-04 23:32:07,730: INFO Initialized: MobileNet v3 pretrained on ImageNet dataset sliced at GAP layer

# %%
image_dir = "C:\\Users\\sdass\\Video to pdf\\5. The CRISP-DM data mining model"

# %%
encodings = cnn.encode_images(image_dir=image_dir)
# Out:
# 2022-11-04 23:32:13,056: INFO Start: Image encoding generation
# 2022-11-04 23:32:15,111: INFO End: Image encoding generation

# %%
encodings
# Out:
# {'5. The CRISP-DM data mining model 01.jpg': array([-0.06905501, -0.01220804, -0.15881842, -0.17248255, -0.34244296,
#         -0.2972193 , -0.2682632 , -0.05665985, -0.0102535 , -0.17704822,
#         -0.34217304, -0.16109388, -0.28956595, -0.29788634, -0.31076807,
#         -0.02126051, -0.3298614 ,  0.04079107, -0.31700587,  0.04941324,
#         -0.32895154, -0.18736495, -0.03289207, -0.33846322, -0.23623663,
#         -0.18794547, -0.13103744, -0.24533673, -0.34710792, -0.33325323,
#         -0.26598564, -0.16130827, -0.03520194, -0.30019557,  0.9157372 ,
#         -0.0416266 , -0.24127923, -0.08917794,  0.1295692 , -0.21481162,
#         -0.14445905, -0.22803408, -0.19707096, -0.1378359 , -0.11205347,
#         -0.3186146 , -0.34989828,  0.4929263 , -0.21180202, -0.2970467 ,
#         -0.20108993, -0.16950461, -0.1785468 , -0.2246031 , -0.28641942,
#         -0.294363  , -0.19079527, -0.12683508, -0.3455606 , -0.23728599,
# ...

# %%
duplicates = cnn.find_duplicates(encoding_map=encodings, scores = True)
# Out:
# 2022-11-04 23:32:25,320: INFO Start: Calculating cosine similarities...
# 2022-11-04 23:32:25,374: INFO End: Calculating cosine similarities.

# %%
type(duplicates)
# Out:
# dict

# %%
duplicates
# Out:
# {'5. The CRISP-DM data mining model 01.jpg': [('5. The CRISP-DM data mining model 02.jpg',
#    1.0)],
#  '5. The CRISP-DM data mining model 02.jpg': [('5. The CRISP-DM data mining model 01.jpg',
#    1.0)],
#  '5. The CRISP-DM data mining model 03.jpg': [('5. The CRISP-DM data mining model 04.jpg',
#    0.99960977),
#   ('5. The CRISP-DM data mining model 05.jpg', 0.99956053)],
#  '5. The CRISP-DM data mining model 04.jpg': [('5. The CRISP-DM data mining model 03.jpg',
#    0.99960977),
#   ('5. The CRISP-DM data mining model 05.jpg', 0.9998853)],
#  '5. The CRISP-DM data mining model 05.jpg': [('5. The CRISP-DM data mining model 03.jpg',
#    0.99956053),
#   ('5. The CRISP-DM data mining model 04.jpg', 0.9998853)],
#  '5. The CRISP-DM data mining model 06.jpg': [],
#  '5. The CRISP-DM data mining model 07.jpg': [('5. The CRISP-DM data mining model 08.jpg',
#    0.99959594)],
#  '5. The CRISP-DM data mining model 08.jpg': [('5. The CRISP-DM data mining model 07.jpg',
# ...

# %%
for key, value in duplicates.items():
   if len(value) > 0:
    print(key + ",")
# Out:
# 5. The CRISP-DM data mining model 01.jpg,
# 5. The CRISP-DM data mining model 02.jpg,
# 5. The CRISP-DM data mining model 03.jpg,
# 5. The CRISP-DM data mining model 04.jpg,
# 5. The CRISP-DM data mining model 05.jpg,
# 5. The CRISP-DM data mining model 07.jpg,
# 5. The CRISP-DM data mining model 08.jpg,
# 5. The CRISP-DM data mining model 10.jpg,
# 5. The CRISP-DM data mining model 11.jpg,
# 5. The CRISP-DM data mining model 12.jpg,
# 5. The CRISP-DM data mining model 13.jpg,
# 5. The CRISP-DM data mining model 14.jpg,
# 5. The CRISP-DM data mining model 16.jpg,
# 5. The CRISP-DM data mining model 17.jpg,
# 5. The CRISP-DM data mining model 18.jpg,
# 5. The CRISP-DM data mining model 19.jpg,
# 5. The CRISP-DM data mining model 20.jpg,
# 5. The CRISP-DM data mining model 21.jpg,
# 5. The CRISP-DM data mining model 22.jpg,
# 5. The CRISP-DM data mining model 23.jpg,
# 5. The CRISP-DM data mining model 24.jpg,
# 5. The CRISP-DM data mining model 25.jpg,
# ...

# %%
# image_dir = "1. Python for data mining"

# %%
# # from imagededup.methods import CNN


# myencoder = CNN()
# duplicates = myencoder.find_duplicates_to_remove(image_dir,min_similarity_threshold=0.85)

# %%
duplicates
# Out:
# {'5. The CRISP-DM data mining model 01.jpg': [('5. The CRISP-DM data mining model 02.jpg',
#    1.0)],
#  '5. The CRISP-DM data mining model 02.jpg': [('5. The CRISP-DM data mining model 01.jpg',
#    1.0)],
#  '5. The CRISP-DM data mining model 03.jpg': [('5. The CRISP-DM data mining model 04.jpg',
#    0.99960977),
#   ('5. The CRISP-DM data mining model 05.jpg', 0.99956053)],
#  '5. The CRISP-DM data mining model 04.jpg': [('5. The CRISP-DM data mining model 03.jpg',
#    0.99960977),
#   ('5. The CRISP-DM data mining model 05.jpg', 0.9998853)],
#  '5. The CRISP-DM data mining model 05.jpg': [('5. The CRISP-DM data mining model 03.jpg',
#    0.99956053),
#   ('5. The CRISP-DM data mining model 04.jpg', 0.9998853)],
#  '5. The CRISP-DM data mining model 06.jpg': [],
#  '5. The CRISP-DM data mining model 07.jpg': [('5. The CRISP-DM data mining model 08.jpg',
#    0.99959594)],
#  '5. The CRISP-DM data mining model 08.jpg': [('5. The CRISP-DM data mining model 07.jpg',
# ...

# %%
plot_duplicates(image_dir=image_dir, duplicate_map=duplicates, filename='5. The CRISP-DM data mining model 37.jpg')

# %%
plot_duplicates(image_dir=image_dir, duplicate_map=duplicates, filename='5. The CRISP-DM data mining model 22.jpg')

# %%
duplicates_2 = cnn.find_duplicates_to_remove(encoding_map=encodings)
# Out:
# 2022-11-04 23:33:47,759: INFO Start: Calculating cosine similarities...
# 2022-11-04 23:33:47,761: INFO End: Calculating cosine similarities.

# %%
len(duplicates_2)
# Out:
# 28

# %%
# import os
# path = "C:\\Users\\sdass\\Video to pdf\\5. The CRISP-DM data mining model"
# os.chdir(path)
# flist = open('DeleteFiles.txt')
# for f in flist:
#     fname = f.rstrip() # or depending on situation: f.rstrip('\n')
#     # or, if you get rid of os.chdir(path) above,
#     # fname = os.path.join(path, f.rstrip())
#     if os.path.isfile(fname): # this makes the code more robust
#         os.remove(fname)

# # also, don't forget to close the text file:
# # flist.close()

# %%
type(duplicates)
# Out:
# dict

# %%
duplicates
# Out:
# {'5. The CRISP-DM data mining model 01.jpg': [('5. The CRISP-DM data mining model 02.jpg',
#    1.0)],
#  '5. The CRISP-DM data mining model 02.jpg': [('5. The CRISP-DM data mining model 01.jpg',
#    1.0)],
#  '5. The CRISP-DM data mining model 03.jpg': [('5. The CRISP-DM data mining model 04.jpg',
#    0.99960977),
#   ('5. The CRISP-DM data mining model 05.jpg', 0.99956053)],
#  '5. The CRISP-DM data mining model 04.jpg': [('5. The CRISP-DM data mining model 03.jpg',
#    0.99960977),
#   ('5. The CRISP-DM data mining model 05.jpg', 0.9998853)],
#  '5. The CRISP-DM data mining model 05.jpg': [('5. The CRISP-DM data mining model 03.jpg',
#    0.99956053),
#   ('5. The CRISP-DM data mining model 04.jpg', 0.9998853)],
#  '5. The CRISP-DM data mining model 06.jpg': [],
#  '5. The CRISP-DM data mining model 07.jpg': [('5. The CRISP-DM data mining model 08.jpg',
#    0.99959594)],
#  '5. The CRISP-DM data mining model 08.jpg': [('5. The CRISP-DM data mining model 07.jpg',
# ...

# %%
c = cnn.find_duplicates(image_dir,min_similarity_threshold=0.85, scores=True)
# Out:
# 2022-11-04 23:33:54,550: INFO Start: Image encoding generation
# 2022-11-04 23:33:56,494: INFO End: Image encoding generation
# 2022-11-04 23:33:56,600: INFO Start: Calculating cosine similarities...
# 2022-11-04 23:33:56,602: INFO End: Calculating cosine similarities.

# %%
import os

# %%
dir_list_all = os.listdir(image_dir)

# %%
dir_list_all
# Out:
# ['5. The CRISP-DM data mining model 01.jpg',
#  '5. The CRISP-DM data mining model 02.jpg',
#  '5. The CRISP-DM data mining model 03.jpg',
#  '5. The CRISP-DM data mining model 04.jpg',
#  '5. The CRISP-DM data mining model 05.jpg',
#  '5. The CRISP-DM data mining model 06.jpg',
#  '5. The CRISP-DM data mining model 07.jpg',
#  '5. The CRISP-DM data mining model 08.jpg',
#  '5. The CRISP-DM data mining model 09.jpg',
#  '5. The CRISP-DM data mining model 10.jpg',
#  '5. The CRISP-DM data mining model 11.jpg',
#  '5. The CRISP-DM data mining model 12.jpg',
#  '5. The CRISP-DM data mining model 13.jpg',
#  '5. The CRISP-DM data mining model 14.jpg',
#  '5. The CRISP-DM data mining model 15.jpg',
#  '5. The CRISP-DM data mining model 16.jpg',
#  '5. The CRISP-DM data mining model 17.jpg',
#  '5. The CRISP-DM data mining model 18.jpg',
#  '5. The CRISP-DM data mining model 19.jpg',
#  '5. The CRISP-DM data mining model 20.jpg',
#  '5. The CRISP-DM data mining model 21.jpg',
# ...

# %%
remaining_elements = [x for x in dir_list_all if x not in duplicates_2]

# %%
remaining_elements
# Out:
# ['5. The CRISP-DM data mining model 01.jpg',
#  '5. The CRISP-DM data mining model 03.jpg',
#  '5. The CRISP-DM data mining model 06.jpg',
#  '5. The CRISP-DM data mining model 07.jpg',
#  '5. The CRISP-DM data mining model 09.jpg',
#  '5. The CRISP-DM data mining model 10.jpg',
#  '5. The CRISP-DM data mining model 13.jpg',
#  '5. The CRISP-DM data mining model 15.jpg',
#  '5. The CRISP-DM data mining model 16.jpg',
#  '5. The CRISP-DM data mining model 22.jpg',
#  '5. The CRISP-DM data mining model 27.jpg',
#  '5. The CRISP-DM data mining model 31.jpg',
#  '5. The CRISP-DM data mining model 38.jpg',
#  '5. The CRISP-DM data mining model 39.jpg']

# %%
list_with_best_info = []
for i in remaining_elements:
#     print(i)
#     plot_duplicates(image_dir=image_dir, duplicate_map=duplicates, filename='5. The CRISP-DM data mining model 37.jpg')
#     print(duplicates[i][-1])
#     print(duplicates[i])
    if duplicates[i]:
        print(duplicates[i][-1][0])
        list_with_best_info.append(duplicates[i][-1][0])
    
    else:
        list_with_best_info.append(i)
# Out:
# 5. The CRISP-DM data mining model 02.jpg
# 5. The CRISP-DM data mining model 05.jpg
# 5. The CRISP-DM data mining model 08.jpg
# 5. The CRISP-DM data mining model 12.jpg
# 5. The CRISP-DM data mining model 14.jpg
# 5. The CRISP-DM data mining model 21.jpg
# 5. The CRISP-DM data mining model 26.jpg
# 5. The CRISP-DM data mining model 30.jpg
# 5. The CRISP-DM data mining model 37.jpg
# 5. The CRISP-DM data mining model 42.jpg

# %%
list_with_best_info
# Out:
# ['5. The CRISP-DM data mining model 02.jpg',
#  '5. The CRISP-DM data mining model 05.jpg',
#  '5. The CRISP-DM data mining model 06.jpg',
#  '5. The CRISP-DM data mining model 08.jpg',
#  '5. The CRISP-DM data mining model 09.jpg',
#  '5. The CRISP-DM data mining model 12.jpg',
#  '5. The CRISP-DM data mining model 14.jpg',
#  '5. The CRISP-DM data mining model 15.jpg',
#  '5. The CRISP-DM data mining model 21.jpg',
#  '5. The CRISP-DM data mining model 26.jpg',
#  '5. The CRISP-DM data mining model 30.jpg',
#  '5. The CRISP-DM data mining model 37.jpg',
#  '5. The CRISP-DM data mining model 42.jpg',
#  '5. The CRISP-DM data mining model 39.jpg']

# %%
# sss = plot_duplicates(image_dir=image_dir, duplicate_map=duplicates, filename='5. The CRISP-DM data mining model 37.jpg')

# %%
sss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9668/1554476465.py in <module>
# ----> 1 sss
#
# NameError: name 'sss' is not defined

# %%
duplicates['5. The CRISP-DM data mining model 37.jpg']
# Out:
# [('5. The CRISP-DM data mining model 31.jpg', 0.9720532),
#  ('5. The CRISP-DM data mining model 32.jpg', 0.9738779),
#  ('5. The CRISP-DM data mining model 33.jpg', 0.99576366),
#  ('5. The CRISP-DM data mining model 34.jpg', 0.99892116),
#  ('5. The CRISP-DM data mining model 35.jpg', 0.99994534),
#  ('5. The CRISP-DM data mining model 36.jpg', 0.9999548)]

# %%
delete_the_elements = [x for x in dir_list_all if x not in list_with_best_info]

# %%
delete_the_elements
# Out:
# ['5. The CRISP-DM data mining model 01.jpg',
#  '5. The CRISP-DM data mining model 03.jpg',
#  '5. The CRISP-DM data mining model 04.jpg',
#  '5. The CRISP-DM data mining model 07.jpg',
#  '5. The CRISP-DM data mining model 10.jpg',
#  '5. The CRISP-DM data mining model 11.jpg',
#  '5. The CRISP-DM data mining model 13.jpg',
#  '5. The CRISP-DM data mining model 16.jpg',
#  '5. The CRISP-DM data mining model 17.jpg',
#  '5. The CRISP-DM data mining model 18.jpg',
#  '5. The CRISP-DM data mining model 19.jpg',
#  '5. The CRISP-DM data mining model 20.jpg',
#  '5. The CRISP-DM data mining model 22.jpg',
#  '5. The CRISP-DM data mining model 23.jpg',
#  '5. The CRISP-DM data mining model 24.jpg',
#  '5. The CRISP-DM data mining model 25.jpg',
#  '5. The CRISP-DM data mining model 27.jpg',
#  '5. The CRISP-DM data mining model 28.jpg',
#  '5. The CRISP-DM data mining model 29.jpg',
#  '5. The CRISP-DM data mining model 31.jpg',
#  '5. The CRISP-DM data mining model 32.jpg',
# ...

# %%
import os
path = "C:\\Users\\sdass\\Video to pdf\\5. The CRISP-DM data mining model"
os.chdir(path)
flist = delete_the_elements
for f in flist:
    fname = f.rstrip() # or depending on situation: f.rstrip('\n')
    # or, if you get rid of os.chdir(path) above,
    # fname = os.path.join(path, f.rstrip())
    if os.path.isfile(fname): # this makes the code more robust
        os.remove(fname)

# also, don't forget to close the text file:
# flist.close()
